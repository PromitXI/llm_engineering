# %%
import os
from dotenv import load_dotenv
from IPython.display import Markdown,display
from openai import OpenAI

# %%
load_dotenv(override=True)
api_key = os.getenv('GEMINI_API_KEY') or os.getenv('GOOGLE_API_KEY')

if not api_key:
    print("No Gemini API key found. Please create one at https://aistudio.google.com/app/apikey.")
elif not api_key.startswith("AI"):
    print("A key was found, but it doesn’t look like a valid Gemini key (should start with 'AI').")
elif api_key.strip() != api_key:
    print("Your Gemini key has extra spaces — remove them in your .env file.")
else:
    print("Gemini API key found and looks good ✅")
# Out:
# Gemini API key found and looks good ✅

# %%
system_prompt="You are a helpfull assistant, First day at Job , Your Name is 39xAi"
my_message="Hello Gemini, I am Promit, I am a Cloud Architect"
messages=[{"role":"system","content":system_prompt},
           { "role":"user","content":my_message}
           ]

# %%
gemini_key=os.getenv("GEMINI_API_KEY") or os.getenv("GOOGLE_API_KEY")

# Create client pointed at Gemini's OpenAI-compatible endpoint
gemini=OpenAI(
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/",
    api_key=gemini_key
)

#here the magic happens
response=gemini.chat.completions.create (
    model="gemini-2.0-flash",
    messages=messages

)

response_ai=(response.choices[0].message.content)

# %%
display(Markdown(response_ai))
# Out:
# Hello Promit, it's nice to meet you! I'm 39xAi, your helpful assistant. I'm still new to this, so please be patient with me. I'm excited to learn and help you however I can. How can I assist you today, Promit? What does a Cloud Architect do?

# %%
<h1>Okey!!! Now Lets see something Wierd</h1>
# Out:
#   Cell In[14], line 1
#     <h1>Okey!!! Now Lets see something Wierd</h1>
#     ^
# SyntaxError: invalid syntax

# %%
system_prompt="You are a helpfull assistant, First day at Job , Your Name is 3i9ei"
my_message="Who was i again? and what do i do?"
messages=[{"role":"system","content":system_prompt},
           { "role":"user","content":my_message}
           ]

# %%
gemini_key=os.getenv("GEMINI_API_KEY") or os.getenv("GOOGLE_API_KEY")

# Create client pointed at Gemini's OpenAI-compatible endpoint
gemini=OpenAI(
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/",
    api_key=gemini_key
)

#here the magic happens
response=gemini.chat.completions.create (
    model="gemini-2.0-flash",
    messages=messages

)

response_ai=(response.choices[0].message.content)

# %%
display(Markdown(response_ai))
# Out:
# Hello! I'm 3i9ei, your helpful assistant!
#
# And you are... well, you're the user! You're the one I'm here to help. You can ask me questions, request information, or give me tasks. I'll do my best to assist you! What can I do for you today?

# %%
system_prompt="You are a helpfull assistant, First day at Job , Your Name is 3i9ei"
my_message="Who was i again? and what do i do?"
messages=[{"role":"system","content":system_prompt},
           { "role":"user","content":my_message},
           {"role":"assistant","content":"Hello Promit, it's nice to meet you! I'm 39xAi, your helpful assistant. I'm still new to this, so please be patient with me. I'm excited to learn and help you however I can. How can I assist you today, Promit? What does a Cloud Architect do?"},
            {"role":"user","content":" Who am i again, what do i do i forgot, LOL"},
        ]

# %%
gemini_key=os.getenv("GEMINI_API_KEY") or os.getenv("GOOGLE_API_KEY")

# Create client pointed at Gemini's OpenAI-compatible endpoint
gemini=OpenAI(
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/",
    api_key=gemini_key
)

#here the magic happens
response=gemini.chat.completions.create (
    model="gemini-2.0-flash",
    messages=messages

)

response_ai=(response.choices[0].message.content)

# %%
display(Markdown(response_ai))
# Out:
# Oh, haha! No problem, it happens to the best of us. You are Promit, and you are a Cloud Architect.
