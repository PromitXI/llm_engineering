# %%
from openai import OpenAI

# %%
import requests
requests.get("http://localhost:11434").content
# Out:
# b'Ollama is running'

# %%
OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ihateterraform')

# %%
response = ollama.chat.completions.create(model="llama3.1:latest", 
messages=[
    {
    "role": "user", 
    "content": "How can an express Route connect to more than one Azure Subscription?"
    }])
response.choices[0].message.content
# Out:
# 'By design, an ExpressRoute connection is tied to a single Microsoft Network Service Provider (MSP) and a specific Azure subscription. However, there are some scenarios that allow an ExpressRoute connection to connect to multiple Azure subscriptions:\n\n1. **Multiple Azure Subscription subscriptions linked under the same Tenant**: If you have multiple Azure subscriptions linked under the same Active Directory (AAD) tenant, you can use a single ExpressRoute connection to connect to all those subscriptions.\n\n2. **Multi-Hub Connectivity**: This option allows your ExpressRoute circuit to be connected to multiple hubs in different regions and then use Azure VPN Gateways for cross-region connectivity across multiple subscriptions.'
