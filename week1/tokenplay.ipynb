# %%
import tiktoken
encoding=tiktoken.encoding_for_model("gpt-4o")
token_ids=encoding.encode("hello There my friend, my only friend.")

# %%
token_ids
# Out:
# [24912, 3274, 922, 5168, 11, 922, 1606, 5168, 13]

# %%
for token in token_ids:
    token_text=encoding.decode([token])
    print("ID:",token,"Text:",token_text)
# Out:
# ID: 24912 Text: hello
# ID: 3274 Text:  There
# ID: 922 Text:  my
# ID: 5168 Text:  friend
# ID: 11 Text: ,
# ID: 922 Text:  my
# ID: 1606 Text:  only
# ID: 5168 Text:  friend
# ID: 13 Text: .
